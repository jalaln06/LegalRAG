# %%
import json
import os

import pandas as pd
from langchain.chains import LLMChain
from langchain.embeddings import OllamaEmbeddings
from langchain.prompts import PromptTemplate
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain_community.llms import Ollama

csv_file_path = 'data/CUAD_v1/master_clauses.csv'
data = pd.read_csv(csv_file_path)

llama_model = Ollama(model="llama3")
embedding_model = OllamaEmbeddings(model="llama3")

documents_path = 'data/CUAD_v1/full_contract_txt/'
vectorstore = Chroma("vdbase", embedding_model)

# %%
def clear_vectorstore(chroma_client):
    try:
        collection = chroma_client._collection
        if collection:
            all_docs = collection.get()
            ids_to_delete = all_docs['ids']

            if ids_to_delete:
                collection.delete(ids=ids_to_delete)
                print(f"Deleted {len(ids_to_delete)} documents from the vector store.")
            else:
                print("No documents to delete.")
        else:
            print("No collection found.")
    except Exception as e:
        print(f"Error clearing vector store: {e}")


def ask_questions(document_name, retriever):
    try:
        columns = [
            'Document Name', 'Parties', 'Agreement Date', 'Effective Date', 'Expiration Date',
            'Renewal Term', 'Notice Period To Terminate Renewal', 'Governing Law',
            'Most Favored Nation', 'Competitive Restriction Exception', 'Non-Compete',
            'Exclusivity', 'No-Solicit Of Customers', 'No-Solicit Of Employees',
            'Non-Disparagement', 'Termination For Convenience', 'Rofr/Rofo/Rofn',
            'Change Of Control', 'Anti-Assignment', 'Revenue/Profit Sharing', 'Price Restrictions',
            'Minimum Commitment', 'Volume Restriction', 'Ip Ownership Assignment',
            'Joint Ip Ownership', 'License Grant', 'Non-Transferable License',
            'Affiliate License-Licensor', 'Affiliate License-Licensee',
            'Unlimited/All-You-Can-Eat-License', 'Irrevocable Or Perpetual License',
            'Source Code Escrow', 'Post-Termination Services', 'Audit Rights',
            'Uncapped Liability', 'Cap On Liability', 'Liquidated Damages',
            'Warranty Duration', 'Insurance', 'Covenant Not To Sue', 'Third Party Beneficiary'
        ]

        answers = {}

        for column in columns:
            question = f"What is the {column.lower().replace('_', ' ')} of the document '{document_name}'?"

            docs = retriever.get_relevant_documents(question)
            context = "\n\n".join([doc.page_content for doc in docs])

            prompt_template = PromptTemplate(template="""
            You're a helpful assistant. Your job is to answer question based on context. Keep your answers short and concise. If there is no answer in provided context just write "No answer" with nothing else.
            Context: {context}\n\nQuestion: {question}
            """, input_variables=["context", "question"])
            chain = LLMChain(llm=llama_model, prompt=prompt_template)

            answer = chain.run({"context": context, "question": question})
            print(answer)
            answers[question] = answer

        return answers
    except Exception as e:
        print(f"Error asking questions for document {document_name}: {e}")
        return {}


results = {}
document_files = [f for f in os.listdir(documents_path) if f.endswith(".txt")]

counter = 0

processed_files = set()
results_files = [f for f in os.listdir() if f.startswith('results_') and f.endswith('.csv')]
for rf in results_files:
    df = pd.read_csv(rf, index_col=0)
    processed_files.update(df.index)

for filename in document_files:
    doc_name = os.path.splitext(filename)[0]
    if doc_name in processed_files:
        print(f"Skipping already processed document: {filename}")
        continue

    try:
        print(f"Processing document: {filename}")
        filepath = os.path.join(documents_path, filename)

        with open(filepath, 'r', encoding='utf-8') as file:
            content = file.read()

        text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
        splits = text_splitter.split_text(content)
        print(f"Document split into chunks. len: {len(splits)}")

        clear_vectorstore(vectorstore)
        print("Vector store cleared.")

        vectorstore.add_texts(splits)
        print("Document chunks added to vector store.")

        retriever = vectorstore.as_retriever(search_kwargs={"k": min(len(splits), 4)})

        doc_results = ask_questions(doc_name, retriever)
        results[doc_name] = doc_results
        counter += 1

        if counter % 3 == 0:
            df = pd.DataFrame(results).T
            df.to_csv(f'results_{counter // 3}.csv', index=True)
            print(f"Results saved to results_{counter // 3}.csv")

    except Exception as e:
        print(f"Error processing document {filename}: {e}")

if counter % 3 != 0:
    df = pd.DataFrame(results).T
    df.to_csv(f'results_{counter // 3 + 1}.csv', index=True)
    print(f"Results saved to results_{counter // 3 + 1}.csv")

for doc_name, answers in results.items():
    print(f"Results for {doc_name}:")
    for question, answer in answers.items():
        print(f"{question}: {answer}")
    print("\n")

results_file = 'results.json'
with open(results_file, 'w') as f:
    json.dump(results, f, indent=4)
# Out:
# Skipping already processed document: LIMEENERGYCO_09_09_1999-EX-10-DISTRIBUTOR AGREEMENT.txt
# Skipping already processed document: WHITESMOKE,INC_11_08_2011-EX-10.26-PROMOTION AND DISTRIBUTION AGREEMENT.txt
# Skipping already processed document: LohaCompanyltd_20191209_F-1_EX-10.16_11917878_EX-10.16_Supply Agreement.txt
# Skipping already processed document: CENTRACKINTERNATIONALINC_10_29_1999-EX-10.3-WEB SITE HOSTING AGREEMENT.txt
# Skipping already processed document: NELNETINC_04_08_2020-EX-1-JOINT FILING AGREEMENT.txt
# Skipping already processed document: ADAMSGOLFINC_03_21_2005-EX-10.17-ENDORSEMENT AGREEMENT.txt
# Skipping already processed document: KIROMICBIOPHARMA,INC_05_11_2020-EX-10.23-CONSULTING AGREEMENT.txt
# Skipping already processed document: VEONEER,INC_02_21_2020-EX-10.11-JOINT VENTURE AGREEMENT.txt
# Skipping already processed document: DovaPharmaceuticalsInc_20181108_10-Q_EX-10.2_11414857_EX-10.2_Promotion Agreement.txt
# Skipping already processed document: PACIRA PHARMACEUTICALS, INC. - A_R STRATEGIC LICENSING, DISTRIBUTION AND MARKETING AGREEMENT .txt
# Skipping already processed document: MetLife, Inc. - Remarketing Agreement.txt
# Skipping already processed document: FTENETWORKS,INC_02_18_2016-EX-99.4-STRATEGIC ALLIANCE AGREEMENT.txt
# Skipping already processed document: DOMINIADVISORTRUST_02_18_2005-EX-99.(H)(2)-SPONSORSHIP AGREEMENT.txt
# Skipping already processed document: PfHospitalityGroupInc_20150923_10-12G_EX-10.1_9266710_EX-10.1_Franchise Agreement3.txt
# Skipping already processed document: CerenceInc_20191002_8-K_EX-10.4_11827494_EX-10.4_Intellectual Property Agreement.txt
# Skipping already processed document: ThriventVariableInsuranceAccountB_20190701_N-6_EX-99.D(IV)_11720968_EX-99.D(IV)_Endorsement Agreement.txt
# Skipping already processed document: ReynoldsConsumerProductsInc_20191115_S-1_EX-10.18_11896469_EX-10.18_Supply Agreement.txt
# Skipping already processed document: IntegrityFunds_20200121_485BPOS_EX-99.E UNDR CONTR_11948727_EX-99.E UNDR CONTR_Service Agreement.txt
# Processing document: PREMIERBIOMEDICALINC_05_14_2020-EX-10.2-INTELLECTUAL PROPERTY AGREEMENT.txt
# Document split into chunks. len: 31
# No documents to delete.
# Vector store cleared.
# Document chunks added to vector store.
# /Users/jalal/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# /Users/jalal/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 0.3.0. Use RunnableSequence, e.g., `prompt | llm` instead.
#   warn_deprecated(
# /Users/jalal/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# Third Addendum to the 2010 Agreement (2020 Agreement)
# The parties to the document are Marv and Premier.
# No answer
# No answer. The context does not mention an "Effective Date" for the agreement. It only mentions that the agreement is executed on a certain date, but does not specify what that date is.
# No answer
# No answer
# No answer. The provided context does not mention a notice period for terminating or renewing the agreement.
# No answer. The provided context does not mention a governing law for the intellectual property agreement.
# No answer
# There is no competitive restriction exception mentioned in this document.
# No answer. The provided context does not contain information about a non-compete clause or any restrictions on competition.
# No answer. The provided context is from an intellectual property agreement and does not mention exclusivity.
# No answer
# No answer
# No answer. The provided context does not contain any mention of a document called "PREMIERBIOMEDICALINC_05_14_2020-EX-10.2-INTELLECTUAL PROPERTY AGREEMENT".
# No answer. The provided context does not mention a termination for convenience clause in the Intellectual Property Agreement.
# Intellectual Property Agreement.
# No answer.
# The anti-assignment provision is:
#
# "THI's (fifty million) stock warrants previously ceded to Mitchell S. Felder by Halberd/THI shall not be eliminated, cancelled, or altered in any way, and for any reason, unless specifically directed at the request of Mitchell S. Felder."
# No answer
# No answer
# No answer. The provided context does not mention a "minimum commitment" or any specific duration for the agreement.
# No answer.
# The intellectual property (IP) ownership assignment in this document appears to be:
#
# * Marv Enterprises, LLC retains ownership of the US provisional patent applications specifically related to methods of treatment for Covid-19 listed in Appendix A (Covid-19 Applications).
# * Premier has an exclusive license to develop and distribute products designed in the Field of Covid-19 Treatment (Covid-19 Licensed Products) based on the Covid-19 Applications.
# * Marv gives its written consent for Premier to assign its rights in the 2010 Agreement/2020 Agreement.
#
# No answer.
# No answer. The provided context does not mention a document with this title or any reference to IP ownership.
# Premier has an exclusive license to the Covid-19 Applications listed in Appendix A, as filed by Marv and licensed via the 2020 Agreement.
# The non-transferable license in this document refers to the fifty million) stock warrants previously ceded to Mitchell S. Felder by Halberd/THI, which shall not be eliminated, cancelled, or altered in any way without the specific direction of Mitchell S. Felder.
# Marv.
# Based on the provided context, Premier has an exclusive license via the 2020 Agreement to Marv's Covid-19 Applications listed in Appendix A.
# No answer
# No answer. This appears to be a contract and not a description of an intellectual property agreement, so there is no "irrevocable or perpetual license" mentioned in the context provided.
# No answer
# No answer
# No answer.
# No answer
# No answer.
# No answer
# No answer
# Intellectual Property Agreement.
# No answer
# No answer. There is no mention of a third-party beneficiary in this document.
# Processing document: SIBANNAC,INC_12_04_2017-EX-2.1-Strategic Alliance Agreement.txt
# Document split into chunks. len: 14
# Deleted 31 documents from the vector store.
# Vector store cleared.
# Document chunks added to vector store.
# Strategic Alliance Agreement
# The parties are Bravatek Technologies, Inc. and Sibannac, Inc.
# The agreement date is November 30, 2017.
# No answer. The context provided does not mention the "SIBANNAC,INC_12_04_2017-EX-2.1-Strategic Alliance Agreement", but rather a different agreement dated November 30, 2017.
# November 30, 2022
# No answer.
# No answer.
# No answer. The provided context does not mention the governing law of the agreement.
# The most favored nation clause is not explicitly mentioned in this document. However, based on the context, it appears that confidentiality and non-disclosure agreements are important aspects of this Strategic Alliance Agreement.
# No answer.
# The non-compete in this document is maintaining in strict confidence and not disclosing or disseminating the Confidential Information disclosed by either party for a period of five (5) years after termination of this Agreement.
# The document "SIBANNAC,INC_12_04_2017-EX-2.1-Strategic Alliance Agreement" appears to be a Strategic Alliance Agreement between Bravatek Technologies, Inc. and Sibannac, Inc., which suggests that it is an exclusive agreement between the two parties regarding certain services and information.
# No answer.
# No answer.
# No answer. This question does not match any information in the provided context.
# No answer (based on provided context). The document does not contain any information regarding the termination of the Strategic Alliance Agreement for convenience.
# The term of this document is "Strategic Alliance Agreement".
# The Change of Control is November 30, 2017.
# No answer.
# According to the document, Bravatek will receive a lead-finder fee ranging from a minimum of 10% to a maximum of 20% of project revenue, depending on the overall project sales margin and cost of development and delivery of each project.
# No answer.
# The minimum commitment of this Strategic Alliance Agreement is for a period of 5 years after termination.
# The volume restriction of this document is 6 pages.
# No answer.
# No answer.
# No answer. This agreement does not appear to include a license grant. It appears to be a confidentiality and non-disclosure agreement related to a strategic alliance between Sibannac, Inc. and Bravatek Technologies, Inc.
# No answer
# No answer
# The affiliates are Bravatek Technologies, Inc. and Sibannac, Inc.
# No answer
# No answer
# No answer.
# The post-termination services are confidentiality obligations, where the parties agree to maintain in strict confidence and not disclose or disseminate Confidential Information for a period of five (5) years after termination of this Strategic Alliance Agreement.
# No answer.
# The uncapped liability in this document is the lead-finder fee, which ranges from a minimum of 10% to a maximum of 20% of project revenue.
# No answer.
# No answer
# No answer.
# No answer
# No answer.
# No answer
# Processing document: INTRICONCORP_03_10_2009-EX-10.22-Strategic Alliance Agreement.txt
# Document split into chunks. len: 74
# Deleted 14 documents from the vector store.
# Vector store cleared.
# Document chunks added to vector store.
# No answer.
# No answer.
# No answer
# No answer.
# No answer. The provided context does not contain information about the expiration date of the document "INTRICONCORP_03_10_2009-EX-10.22-Strategic Alliance Agreement".
# No answer. The provided context does not mention a "renewal term". It appears to be a Strategic Alliance Agreement between IntriCon and Dynamic Hearing, covering topics such as insolvency, termination, maintenance, infringement, and regulatory approvals.
# No answer. There is no mention of a notice period for terminating the agreement in this context.
# No answer. The provided context does not mention the governing law of the document.
# Australia, as Dynamic Hearing Pty Ltd is an Australian company.
# No answer. The context provided does not mention a "competitive restriction exception".
# No answer
# No answer. The provided context does not mention a document called "INTRICONCORP_03_10_2009-EX-10.22-Strategic Alliance Agreement".
# No answer.
# No answer.
# No answer. The context only mentions the contents of the agreement, not any provisions related to disparagement.
# (b) sells a significant portion of its assets or undertaking.
# The answer can be found in the context provided.
#
# The Strategic Alliance Agreement between IntriCon and Dynamic Hearing is an agreement to collaborate on certain technologies and products. The document outlines terms and conditions for their collaboration, including provisions related to intellectual property, confidentiality, and termination of the agreement under certain circumstances, such as insolvency or sale of a significant portion of assets.
#
# So, in this case, the "rofr/rofo/rofn" is likely a typo and should be "purpose". The purpose of this document is to outline the terms and conditions of the strategic alliance between IntriCon and Dynamic Hearing.
# (b) sells a significant portion of its assets or undertaking.
# No answer. The context does not mention assignment of this agreement.
# No answer. The provided context does not mention revenue or profit sharing.
# No answer.
# A strategic alliance agreement dated July 16, 2008, between Dynamic Hearing Pty Ltd and IntriCon Corporation.
# No answer. This question appears to be outside the context provided, which only includes a Strategic Alliance Agreement and its exhibits. The document does not mention volume restriction.
# No answer. The provided context does not address intellectual property (IP) ownership assignment.
# No answer. The provided context does not mention "joint ip ownership" or any similar term related to intellectual property.
# No answer.
# No answer (based on provided context)
# Dynamic Hearing
# Dynamic Hearing PTY LTD
# No answer.
# No answer.
# No answer. The provided context does not mention "source code escrow".
# No answer.
# No answer. The provided context does not mention audit rights.
# No answer. The context only mentions termination of agreement if Dynamic Hearing sells a significant portion of its assets or undertaking, but it does not specify any uncapped liability.
# No answer. The provided context does not mention a cap on liability for this document.
# No answer. The context provided does not mention liquidated damages.
# No answer. The provided context does not mention warranty duration.
# The answer is "No Answer" because the provided context does not mention anything about an insurance of a document. The text appears to be a Strategic Alliance Agreement between IntriCon and Dynamic Hearing, outlining their rights and obligations regarding certain technologies.
# Dynamic Hearing's covenant not to sue is described in Section 11.4 (b) - sells a significant portion of its assets or undertaking.
# HIMSA and HIMPP.
# Results saved to results_1.csv
# Processing document: BONTONSTORESINC_04_20_2018-EX-99.3-AGENCY AGREEMENT.txt
# Document split into chunks. len: 236
# Deleted 74 documents from the vector store.
# Vector store cleared.
# Document chunks added to vector store.
# MFW Doc 632-1
# The parties are not explicitly stated in the provided context, but based on the context and language used, it can be inferred that the parties include Merchant (the debtor), Agent, and Purchaser, along with other entities and individuals mentioned in the document.
# No answer
# No answer.
# No answer. The provided context does not mention an expiration date for the document "BONTONSTORESINC_04_20_2018-EX-99.3-AGENCY AGREEMENT".
# No answer
# No answer
# No answer
# The most favored nation is Delaware.
# No answer
# No answer
# No answer. The provided context does not mention the document "BONTONSTORESINC_04_20_2018-EX-99.3-AGENCY AGREEMENT" at all.
# No answer
# No answer.
# No answer.
# No answer.
# No answer.
# No answer. This context does not provide any information about a "change of control" related to the document 'BONTONSTORESINC_04_20_2018-EX-99.3-AGENCY AGREEMENT'.
# No answer
# No answer. The provided context does not mention revenue or profit sharing.
# No answer
# No answer
# No answer
# No answer. The provided context is about Employee Matters, not IP ownership.
# No answer.
# No answer
# A limited license and right to use all Intellectual Property for purposes of conducting the GOB Sale and otherwise marketing any or all of the Assets.
# The Bankruptcy Court for the District of Delaware.
# No answer. The provided context does not mention an "affiliate license-licensee" or any related information that would allow me to answer this question.
# No answer.
# No answer. The context does not provide information about an "irrevocable or perpetual license" related to a specific document ("BONTONSTORESINC_04_20_2018-EX-99.3-AGENCY AGREEMENT").
# No answer
# No answer
# No answer. This context does not mention "audit rights". It appears to be a legal document related to bankruptcy and asset sales, with numerical data on various stores. There is no mention of audit rights in this context.
# No answer.
# No answer. This context does not mention a cap on liability for the "Agency Agreement".
# No answer.
# No answer
# No answer.
# No answer
# No answer. The context does not mention a "third-party beneficiary" or any specific entity that would be considered a third-party beneficiary.
# Processing document: ON2TECHNOLOGIES,INC_11_17_2006-EX-10.3-SUPPORT AND MAINTENANCE AGREEMENT.txt
# Document split into chunks. len: 83
# Deleted 236 documents from the vector store.
# Vector store cleared.
# Document chunks added to vector store.
# No answer.
# Wildform and On2 are the parties in this document, an Support and Maintenance Agreement dated November 17, 2006.
# No answer. There is no mention of an "agreement date" in this document.
# No answer.
# No answer
# No answer. The provided context does not mention a support and maintenance agreement or a renewal term.
# No answer. The provided context does not mention a notice period for terminating the renewal of the agreement.
# No answer.
# No answer
# No answer. The context does not provide information about a "competitive restriction exception".
# No answer. The provided context does not contain information about a non-compete clause.
# The exclusivity of this document, 'ON2 TECHNOLOGIES, INC _11_17_2006 - EX-10.3 SUPPORT AND MAINTENANCE AGREEMENT', is the intellectual property and rights in the Incorporated Technology Works, which belong exclusively to On2.
# No answer. The context does not mention the solicitation of customers. It appears to be a support and maintenance agreement between Wildform and On2 Technologies, Inc.
# No answer. The context provided does not mention the "no-solicit" of employees.
# No answer
# No answer
# No answer.
# No answer
# No answer. The text does not mention an anti-assignment provision for this document.
# No answer
# No answer. The provided context does not mention any pricing or financial information related to a "Support and Maintenance Agreement".
# No answer
# No answer.
# No answer. This question appears to be asking about intellectual property (IP) ownership assignment, but there is no relevant information provided in the given context. The text only discusses various software products and their branding changes from Wildform to On2.
# No answer. The provided context does not mention joint IP ownership.
# No answer. The provided context does not mention a "license grant" or any specific agreement details.
# The non-transferable license mentioned in this document refers to the technical support provided by Wildform to On2 during the first twelve months of the Term. This support includes training On2 personnel on how the code works, design, maintenance, and compilation of software, as well as other reasonable technical assistance via phone and email.
# No answer.
# No answer. The provided context does not mention an "affiliate license-licensee".
# No answer.
# No answer.
# No answer. The provided context does not contain information about source code escrow.
# No answer
# No answer. The provided context does not mention anything about audit rights. It appears to be a support and maintenance agreement for software development products.
# No answer. The context does not provide information about uncapped liability in this agreement.
# No answer. The document does not specify a cap on liability.
# No answer. This document appears to be a support and maintenance agreement between On2 Technologies, Inc. and Wildform, and does not mention liquidated damages.
# No answer.
# No answer.
# No answer.
# Macromedia and Microsoft.
# Processing document: Freecook_20180605_S-1_EX-10.3_11233807_EX-10.3_Hosting Agreement.txt
# Document split into chunks. len: 11
# Deleted 83 documents from the vector store.
# Vector store cleared.
# Document chunks added to vector store.
# Error asking questions for document Freecook_20180605_S-1_EX-10.3_11233807_EX-10.3_Hosting Agreement: Cannot return the results in a contigious 2D array. Probably ef or M is too small
# Results saved to results_2.csv
# Processing document: OPERALTD_04_30_2020-EX-4.14-SERVICE AGREEMENT.txt
# Document split into chunks. len: 27
# Deleted 11 documents from the vector store.
# Vector store cleared.
# Document chunks added to vector store.
# Service Agreement
# The parties to this Service Agreement are PC Financial and Mobimagic.
# No answer.
# No answer. There is no mention of an effective date in this context.
# No answer. The provided context does not mention an expiration date for the Service Agreement.
# No answer
# Thirty (30) days.
# No answer. The provided context does not mention a governing law for this Agreement.
# Based on the provided context, there is no explicit mention of a "most favored nation" clause in this Service Agreement. Therefore, my answer would be:
#
# No answer
# No answer. The provided context does not mention a "competitive restriction" exception in the Service Agreement.
# Based on the provided context, I can answer your question.
#
# The Service Agreement refers to a contract between PC Financial and Mobimagic, which outlines the services to be performed by Mobimagic during the Service Period. The agreement also discusses intellectual property rights, termination clauses, and more.
#
# So, the non-compete of the document is: **SERVICE AGREEMENT**
# This appears to be a Service Agreement between PC Financial and Mobimagic, dated March 30, 2020.
# No answer.
# No answer.
# No answer
# No answer. The termination clause (9.3) in the provided context only mentions automatic termination due to certain events, such as receiver appointment or bankruptcy, but does not mention termination for convenience.
# Service Agreement
# No answer
# The anti-assignment clause in this Service Agreement states that neither party may assign, delegate, or transfer their rights and obligations under this agreement without the other party's express prior written consent.
# No answer
# No answer. The provided context does not mention any price restrictions.
# Service Period.
# No answer
# No answer. The provided context does not discuss IP ownership assignment in this specific agreement.
# No answer. The context does not provide information about joint IP ownership.
# No answer.
# This agreement may not be assigned, delegated, or otherwise transferred, in whole or in part, by operation of law or otherwise, by a Party without the other Party's express prior written consent. (Clause 10.5)
# PC Financial
# No answer.
# No answer
# No answer
# No answer
# No answer. The context only provides the terms of a service agreement between Mobimagic and PC Financial, it does not mention anything about "post-termination services".
# No answer. There is no mention of "audit rights" in this document.
# No answer.
# No answer
# No answer.
# No answer. There is no mention of a "warranty duration" in this document.
# Service Agreement.
# No answer. The provided context does not mention a "covenant not to sue".
# No answer. The provided context does not mention a third-party beneficiary.
# Processing document: BORROWMONEYCOM,INC_06_11_2020-EX-10.1-JOINT VENTURE AGREEMENT.txt
# Document split into chunks. len: 31
# Deleted 27 documents from the vector store.
# Vector store cleared.
# Document chunks added to vector store.
# Joint Venture Agreement
# The parties to the Joint Venture Agreement are:
#
# * BorrowMoney.com, inc (also referred to as "BorrowMoney.com, inc of 512 Bayshore DR, suite 201 Fort Lauderdale FL 33304")
# * JVLS, LLC dba Vaccines 2Go (also referred to as "4060 Johns Creek Parkway Suite H Suwanee, GA 30024")
# No answer
# No answer
# No answer
# No answer.
# No answer
# Florida
# IT Development.
# No answer
# No answer. This appears to be a Joint Venture Agreement and does not contain a non-compete clause.
# This appears to be a Joint Venture Agreement between BorrowMoney.com, inc and JVLS, LLC dba Vaccines 2Go.
# No answer. This question appears to be outside the scope of the provided context, which is a joint venture agreement. There is no "no-solicit" clause in this document.
# No answer.
# No answer
# No answer
# A Joint Venture Agreement.
# No answer
# Anti-Assignment: A Member who assigns any or all of their Venture interest to any third party will relinquish their status as Member including all management and voting rights. Assignment of Member status, under this clause, including any management and voting interests, will require the consent of all the remaining Members.
# The revenue/profit sharing of BorrowMoney.com, inc is $60,000.00 USD from monthly government, city, and state, and or private awarded contracts. Plus 10% of any generated gross revenue, in addition to the total contributions.
# No answer. The provided context does not mention a specific "price restriction" related to the Joint Venture Agreement.
# The minimum commitment is $3,500,000.00 USD.
# No answer. The context does not provide information about a specific volume restriction for the document "BORROWMONEYCOM,INC_06_11_2020-EX-10.1- JOINT VENTURE AGREEMENT".
# No answer
# No answer.
# No answer. The provided context does not mention a "license grant" in relation to the Joint Venture Agreement.
# No answer. The provided context does not mention a non-transferable license in the Joint Venture Agreement.
# JVLS, LLC dba Vaccines 2Go
# JVLS, LLC dba Vaccines 2Go
# No answer. The provided context appears to be a joint venture agreement, not related to an unlimited or all-you-can-eat license.
# No answer.
# No answer
# No answer.
# No answer. The provided context does not mention audit rights for the Joint Venture Agreement.
# $3,500,000.00 USD
# No answer.
# No answer
# No answer
# This appears to be a Joint Venture Agreement.
# No answer.
# The Venture itself (Vaccines 2Go) and its members (JVLS, LLC).
# Processing document: ZEBRATECHNOLOGIESCORP_04_16_2014-EX-10.1-INTELLECTUAL PROPERTY AGREEMENT.txt
# Document split into chunks. len: 181
# Deleted 31 documents from the vector store.
# Vector store cleared.
# Document chunks added to vector store.
# Intellectual Property Agreement
# No answer.
# No answer
# No answer. The context does not provide any information about the effective date of the Intellectual Property Agreement.
# No answer.
# No answer.
# No answer. The provided context does not mention a specific notice period for terminating the renewal of the Intellectual Property Agreement.
# No answer
# No answer.
# No answer.
# No answer. The provided context does not mention a non-compete clause.
# No answer. The provided context does not mention the "exclusivity" term, and this question is not related to any specific concept or definition presented in the given text.
# No answer
# No answer.
# No answer.
# No answer.
# No answer. The provided context does not mention "rofr", "rofo", or "rofn" at all.
# No answer.
# No answer. This question does not relate to any specific section or term defined in the provided context.
# No answer
# No answer.
# No answer.
# No answer
# No answer
# No answer
# Reciprocal License.
# Reciprocal License.
# No answer
# No answer.
# Reciprocal License
# Reciprocal License.
# No answer. The context does not mention source code escrow.
# No answer.
# No answer. The provided context does not mention "audit rights". It appears to be a intellectual property agreement related to software licenses and patents.
# No answer. The provided context only describes various terms and their meanings, but does not provide any information about uncapped liability.
# No answer. The context does not mention a specific cap on liability.
# No answer
# No answer
# No answer
# No answer.
# No answer. The provided context does not mention a "third party beneficiary".
# Results saved to results_3.csv
# Processing document: ChinaRealEstateInformationCorp_20090929_F-1_EX-10.32_4771615_EX-10.32_Content License Agreement.txt
# Document split into chunks. len: 73
# Deleted 181 documents from the vector store.
# Vector store cleared.
# Document chunks added to vector store.
# The answer can be found in the context:
#
# "Source: CHINA REAL ESTATE INFORMATION CORP, F-1, 9/29/2009"
#
# So, the document name is "F-1".
# The parties to this document are China Real Estate Information Corp (CRIC) and E-House Holdings Limited, SINA Corporation.
# No answer
# No answer. The provided context does not mention an "F-10.32" or a "Content License Agreement", but rather a Termination Agreement and an Agency Agreement.
# No answer.
# No answer
# No answer. The provided context does not mention a specific notice period for terminating or renewing the document.
# The governing law of this document is the laws of the People's Republic of China (without regard to its conflicts of laws rules).
# No answer
# No answer
# No answer
# Exclusive control of the defense, settlement and/or compromise of an Action (provided that Licensee may not settle any Action in a manner that adversely affects Licensor without Licensor's prior written consent, not to be unreasonably withheld or delayed).
# A Content License Agreement.
# No answer.
# A Content License Agreement.
# No answer (since this question is not related to the provided context, which is an "Agency Agreement" between SINA Corporation and China Online Housing Technology Corporation).
# The roof is not provided in this context, as it appears to be a filing with the SEC (Securities and Exchange Commission) that includes various agreements, including the Content License Agreement.
# According to the context, "Change of Control" means (i) an acquisition or purchase by any Person or related group of Persons that results in a Competitor owning more ordinary shares in CRIC than E-House and SINA, and their respective controlled Affiliates, own in aggregate; or (ii) an event where a Competitor acquires the right to nominate a member to the board of directors of CRIC.
# The answer is "No Answer". The context does not provide an explanation for this specific document, which appears to be a content license agreement between China Real Estate Information Corp and another party (Licensor/Licensee).
# No answer.
# No answer
# No answer
# No answer.
# Exclusive control of the defense, settlement and/or compromise of an Action (provided that Licensee may not settle any Action in a manner that adversely affects Licensor without Licensor's prior written consent, not to be unreasonably withheld or delayed).
# No answer
# An exclusive, non-transferable (except as set forth in Section 10.7) and non-sublicensable (except as provided in Section 2.1(c)) license to use the Licensed Content in connection with websites associated with the Licensed Domain Names until the earlier of (i) termination or expiration of this Agreement, or (ii) termination or expiration of the Agency Agreement.
# The non-transferable license is a exclusive, non-transferable (except as set forth in Section 10.7) and non-sublicensable (except as provided in Section 2.1(c)) license to use the Licensed Content in connection with websites associated with the Licensed Domain Names until the earlier of termination or expiration of this Agreement, or termination or expiration of the Agency Agreement.
# Licensor.
# Licensee.
# No answer.
# No answer
# The source code is not explicitly mentioned in this document. However, it is likely that the "Content" refers to the intellectual property and information being licensed under this agreement.
# No answer.
# No answer
# No answer.
# No answer.
# No answer. The context does not mention "liquidated damages" at all.
# No answer
# A "Content License Agreement".
# The covenant not to sue in this document is that neither party will make any public announcement or communicate with news media regarding the agreement or contemplated transactions without the prior written consent of the other party, unless required by law or applicable stock exchange regulation.
# Licensor and Licensee are the parties to this agreement, not a third-party beneficiary.
# Processing document: HERTZGLOBALHOLDINGS,INC_07_07_2016-EX-10.4-INTELLECTUAL PROPERTY AGREEMENT.txt
# Document split into chunks. len: 43
# Deleted 73 documents from the vector store.
# Vector store cleared.
# Document chunks added to vector store.
# Intellectual Property Agreement
# The parties to this Intellectual Property Agreement are:
#
# 1. THE HERTZ CORPORATION
# 2. HERTZ SYSTEM, INC.
# 3. HERC RENTALS INC.
#
# Note: These are the same entities that have executed the agreement on behalf of their respective officers as stated at the beginning of the document.
# No answer (the provided context does not specify an agreement date).
# No answer. The provided context does not mention an "effective date" for this Agreement.
# No answer. The provided context does not contain an expiration date for the document "INTELLECTUAL PROPERTY AGREEMENT".
# No answer
# No answer
# No answer.
# No answer. The provided context does not mention a "most favored nation" clause or any reference to such a concept.
# No answer. There is no section or clause mentioned as "competitive restriction exception" in this document.
# No answer.
# Intellectual Property Agreement.
# No answer
# No answer
# No answer.
# No answer
# No answer.
# No answer. The provided context does not mention a "change of control".
# No answer. The context does not mention assignment of the document or any provisions related to it.
# No answer. This document is an Intellectual Property Agreement and does not contain any information about revenue or profit sharing.
# No answer.
# No answer
# No answer. The provided context does not mention a "volume restriction".
# HSI (HERTZ) owns the HSI (HERTZ) Foreign ERB Trademarks and HERC (HERTZ) US ERB Trademarks. HERC owns certain US trademarks not derived from the HERTZ trademark, including the trademarks HERC RENTALS and HERCRENTALS Logo.
# The intellectual property agreement describes joint IP ownership between THE HERTZ CORPORATION (HSI), HERTZ SYSTEMS, INC., and HERC RENTALS INC.
# No answer. This text appears to be a section of an intellectual property agreement and does not contain a specific license grant.
# No answer.
# The Hertz Corporation and Hertz System, Inc. are both affiliate license- licensors of this document.
# No answer. The provided context does not mention any affiliate license-licensees.
# No answer.
# No answer
# No answer
# The post-termination services mentioned in this Intellectual Property Agreement are not explicitly stated. The agreement does mention that HSI and HERC will cooperate to ensure no confusion arises in the worldwide marketplace regarding ERB trademarks, but it does not specify any ongoing obligations or services after the termination of the agreement. Therefore, I must answer: "No answer".
# No answer.
# No answer.
# No answer.
# No answer. There is no mention of liquidated damages in this intellectual property agreement.
# No answer. The provided context does not mention a warranty duration for any intellectual property agreement.
# The answer is that there is no mention of "insurance" in this document, so I will write: "No answer".
# There is no specific section titled "Covenant Not To Sue" in this document. However, Article 2.13 mentions that nothing in the agreement or ancillary agreements shall affect or limit the rights confirmed in the license between HSI and HERC, which remain in full force and effect until the later of the expiration of the Interim Period or the final determination or resolution of the action pending as T-409-16.
#
# Therefore, it can be inferred that a covenant not to sue exists, but it is not explicitly stated in this document.
# No answer.
# Processing document: GLOBALTECHNOLOGIESLTD_06_08_2020-EX-10.16-CONSULTING AGREEMENT.txt
# Document split into chunks. len: 29
# Deleted 43 documents from the vector store.
# Vector store cleared.
# Document chunks added to vector store.
# Exhibit 10.16 CONSULTING AGREEMENT
# The parties to this document are Global Technologies, Ltd (also referred to as "Company") and Timothy Cabrera (referred to as "Consultant").
# January 2, 2020
# The effective date of this Consulting Agreement is January 2nd, 2020.
# No answer. There is no mention of an expiration date in the provided context.
# No answer. The provided context does not mention a "renewal term".
# No answer. There is no mention of a notice period for terminating or renewing this consulting agreement in the provided context.
# The governing law of the Consulting Agreement is the laws of the State of Florida, without regard to its conflict of law doctrine.
# Florida
# No answer.
# No answer. The provided context does not contain any information about a non-compete clause or agreement.
# The exclusivity of this Consulting Agreement is non-exclusive, meaning Consultant may provide services to other parties in addition to the Company.
# No answer.
# No answer. The provided context does not mention any "no-solicitation" clause or policy regarding employees of Global Technologies, Ltd.
# No answer
# No answer
# The role/form of the document "GLOBALTECHNOLOGIESLTD_06_08_2020-EX-10.16-CONSULTING AGREEMENT" is a Consulting Agreement.
# No answer. The provided context does not mention "change of control".
# The anti-assignment provision in this document is "No assignment". This means that the parties cannot assign their rights or obligations under this agreement without the prior written consent of the other party.
# No answer.
# No answer
# The minimum commitment is "January 2nd, 2020".
# No answer. The provided context does not mention a volume restriction.
# No answer. The provided context does not mention intellectual property (IP) ownership or assignment, so there is no relevant information to provide an answer.
# The joint ip ownership of this document is not explicitly stated in the provided context.
# No answer.
# No answer.
# Global Technologies, Ltd.
# Global Technologies, Ltd.
# No answer. This is a consulting agreement, not a license.
# No answer.
# No answer.
# No answer.
# No answer. The provided context does not contain any information about audit rights.
# The uncapped liability of this document, referred to as Exhibit 10.16 CONSULTING AGREEMENT, is not explicitly stated. However, the indemnification clause in Article 7 suggests that the Company may be liable for costs and expenses related to claims or matters arising from the Consultant's services. The extent of this liability is not capped, implying an uncapped liability.
# No answer
# No answer
# No answer. The provided context does not contain information about warranty duration.
# The insurance of this document (GLOBAL TECHNOLOGIES LTD_06_08_2020-EX-10.16-CO NSULTING AGREEMENT) is liability insurance, specifically indemnification obligations for the Parties' mutual promises contained in the agreement.
# No answer. There is no "Covenant Not To Sue" mentioned in this document.
# No answer. There is no indication in this agreement that a third-party beneficiary exists.
# Results saved to results_4.csv
# Processing document: PfHospitalityGroupInc_20150923_10-12G_EX-10.1_9266710_EX-10.1_Franchise Agreement1.txt
# Document split into chunks. len: 236
# Deleted 29 documents from the vector store.
# Vector store cleared.
# Document chunks added to vector store.
# No answer
# The parties to the Franchise Agreement are Pizza Fusion Holdings, Inc. and the Franchisee (name not specified).
# No answer
# The effective date of the document "PfHospitalityGroupInc_20150923_10-12G_EX-10.1_9266710_EX-10.1_FranchiseAgreement1" is September 23, 2015.
# No answer
# No answer
# No answer
# No answer (based on provided context).
# No answer. The provided context appears to be a franchise agreement, but there is no mention of the "most favored nation".
# No answer.
# No answer. The provided context does not mention a non-compete clause or any related information.
# No answer
# No answer.
# No answer
# No answer
# No answer.
# The format of the document "PF HOSPITALITY GROUP INC., 10-12G, 9/23/2015" appears to be a Franchise Agreement.
# No answer
# No answer
# No answer. The provided context does not mention revenue/profit sharing.
# No answer. The provided context does not contain information about price restrictions in the Franchise Agreement.
# Nine months after the Agreement Date.
# No answer. This appears to be a legal document and not a technical or scientific context that would have volume restrictions.
# No answer.
# No answer.
# No answer.
# No answer.
# No answer. The provided context does not mention an "affiliate license-licensor" or a specific document with that name.
# No answer. The context does not provide information about an affiliate license or licensee.
# No answer. The context does not mention an "unlimited/all-you-can-eat-license".
# No answer.
# The source code for the document "PfHospitalityGroupInc_20150923_10-12G_ EX-10.1_9266710_ EX-10.1_FranchiseAgreement1" is PF HOSPITALITY GROUP INC., 10-12G, 9/23/2015.
# No answer.
# No answer.
# No answer
# No answer.
# No answer. The context does not mention "liquidated damages" in the provided excerpt from the Franchise Agreement.
# No answer
# No answer.
# No answer
# Us.
# Processing document: CORIOINC_07_20_2000-EX-10.5-LICENSE AND HOSTING AGREEMENT.txt
# Document split into chunks. len: 92
# Deleted 236 documents from the vector store.
# Vector store cleared.
# Document chunks added to vector store.
# No answer
# No answer. The context provided does not mention the "parties" referring to a specific document, but rather it seems to be describing a license and hosting agreement.
# No answer
# No answer.
# No answer. The provided context does not mention an expiration date for this document.
# No answer.
# No answer. The provided context does not mention a notice period for terminating the renewal of this document.
# No answer. The context does not mention the governing law of the document.
# No answer
# No answer
# The non-compete of this document is a "License and Hosting Agreement".
# No answer.
# No answer
# No answer
# No answer. The provided context does not mention the document "CORIOINC_07_20_2000-EX-10.5-LICENSE AND HOSTING AGREEMENT" or its contents, including non-disparagement.
# No answer. The provided context does not mention the termination clause or any specific termination terms for convenience.
# A license and hosting agreement for Commerce One!
# No answer. The provided context does not mention anything about a change of control.
# No answer.
# No answer.
# No answer.
# The minimum commitment of this license agreement is not explicitly stated, but it appears to be a long-term agreement based on the duration of service hours and support availability.
# No answer
# No answer. The context does not provide information about the IP ownership assignment of the document.
# No answer.
# No answer. The context does not provide information about a license grant.
# No answer. The question is about a license, but there are no relevant details provided in this context.
# Commerce One
# No answer.
# SOFTWARE USER: Unlimited
# No answer. The context does not provide an answer to this specific question.
# No answer
# No answer.
# No answer
# No answer. The provided context does not mention any uncapped liability.
# No answer.
# No answer. The provided context does not mention liquidated damages.
# No answer
# No answer.
# No answer. The provided context does not mention a "covenant not to sue".
# No answer.
# Processing document: TUNIUCORP_03_06_2014-EX-10-COOPERATION AGREEMENT.txt
# Document split into chunks. len: 25
# Deleted 92 documents from the vector store.
# Vector store cleared.
# Document chunks added to vector store.
# Cooperation Agreement
# Nanjing Tuniu Technology Co., Ltd. (Party A) and Beijing Tuniu Technology Co., Ltd. (Party B).
# The agreement date of the document "TUNIUCORP_03_06_2014-EX-10-COOPERATION AGREEMENT" is not explicitly stated in the provided context. No answer.
# No answer. The provided context does not mention an "effective date" for the Cooperation Agreement.
# No answer. The context does not provide an expiration date for the "Cooperation Agreement".
# No answer
# No answer. The provided context does not mention a notice period for terminating the renewal of the Cooperation Agreement.
# No answer. The context provided does not mention the governing law of the agreement.
# No answer.
# According to Article 2.3, Party A shall not conduct any other business or make any commercial arrangement without Party B's consent, except as provided in the document.
# No answer. The provided context does not mention a "non-compete" or any restrictions on competing with each other.
# The exclusivity of the document "TUNIUCORP_03_06_2014-EX-10-COOPERATION AGREEMENT" is that it outlines a cooperation agreement between Nanjing Tuniu Technology Co., Ltd. (Party A) and Beijing Tuniu Technology Co., Ltd. (Party B), regarding the provision of various services, including research, development, production, testing, operation, maintenance, upgrade, and consultancy services related to tour products and internet platforms.
# No answer.
# The confidentiality obligations specified hereunder.
# No answer. The context does not provide any information about a "non-disparagement" document called 'TUNIUCORP_03_06_2014-EX-10-CONCORPORATION AGREEMENT'.
# No answer.
# Cooperation Agreement
# No answer.
# According to Article 12.2, the rights and obligations under this Agreement shall not be transferred, except for the transfer by Party B to its affiliates. Therefore, the anti-assignment clause is that the Agreement cannot be assigned or transferred by either party, unless it's a transfer by Party B to its affiliates.
# No answer. The provided context does not mention revenue or profit sharing.
# No answer.
# No answer.
# No answer
# Party B owns all intellectual property researched and developed, created and invented by both Parties in the course of performing this Agreement.
# The Parties agree that any and all intellectual property researched and developed, created and invented by the Parties (including their employees) in the course of performance of this Agreement shall be owned by Party B.
# No answer. The context does not mention a license grant, and there is no relevant information in the provided text to determine what kind of license might be granted.
# No answer
# Party B.
# No answer. This context does not provide information about affiliate or licensee, as it only discusses transfer of rights and obligations under Article 12.2.
# No answer.
# No answer.
# No answer.
# No answer.
# No answer. This agreement does not mention audit rights.
# No answer
# No answer. The provided context does not mention a "cap on liability" or any specific limitation on the amount of liability.
# No answer. The provided context does not mention "liquidated damages".
# No answer
# EXHIBIT 10
# No answer.
# No answer.
# Results saved to results_5.csv
# Processing document: CYBERIANOUTPOSTINC_07_09_1998-EX-10.13-PROMOTION AGREEMENT.txt
# Document split into chunks. len: 33
# Deleted 25 documents from the vector store.
# Vector store cleared.
# Document chunks added to vector store.
# The document name is "PROMOTION AGREEMENT".
# Based on the provided context, the party to the document "CYBERIAN OUTPOST INC_07_09_1998-EX-10.13-PROMOTION AGREEMENT" is:
#
# * Cyberian Outpost (the Company)
# * CNET, Inc.
# No answer
# No answer. There is no mention of an effective date in the provided context.
# No answer.
# No answer. The provided context does not mention the renewal term of the "Promotion Agreement".
# No answer. There is no mention of a notice period for terminating or renewing the agreement in this document.
# No answer
# The most favored nation is not explicitly stated in the provided document, but based on the context, it appears to be related to advertising banners and retail promotions between CNET and Cyberian Outpost.
# No answer. There is no mention of "competitive restriction exception" in the provided document.
# The non-compete clause is "1.   The Company Site and the Company's related operations must comply with the following performance standards throughout the Term".
# The document "Cyberian Outpost INC_07_09_1998-EX-10.13-PROMOTION AGREEMENT" appears to be a promotion agreement between Cyberian Outpost and CNET, Inc., outlining the terms of their partnership and the display of pre-filled links on various CNET websites.
# No answer.
# The exhibit is titled "PROMOTION AGREEMENT".
# No answer. The document 'CyberianOutpostInc_07_09_1998-EX-10.13-PROMOTION AGREEMENT' is a Promotion Agreement, not a non-disparagement agreement.
# No answer.
# No answer
# No answer
# No answer. The context does not indicate that there is an anti-assignment provision in this document, which is a promotion agreement between CNET and the Company.
# No answer. The provided context does not mention a specific revenue or profit sharing percentage. It only discusses advertising banners and performance standards.
# No answer. The document does not mention a specific price or restriction on pricing. It discusses advertising banners and retail promotions, but does not provide information on the cost of these programs.
# No answer (there is no mention of a "minimum commitment" in the provided context).
# No answer.
# No answer.
# No answer.
# The Company grants CNET a non-exclusive, royalty-free license to use, display and publish any of the Company trademarks, tradenames, service marks and logos for inclusion in the Promotions, solely for use in connection with the Promotions.
# ...
# Document chunks added to vector store.
# No answer.
# The parties are Todos Medical Ltd. and Care G. B. Plus Ltd.
# No answer.
# No answer. The provided context does not mention the effective date of the "Reseller Agreement".
# No answer
# No answer. The provided context does not mention a renewal term for this agreement.
# No answer.
# No answer
# No answer.
# No answer.
# No answer. The provided context does not mention a non-compete clause in the document "TodosMedicalLtd_20190328_20-F_EX-4.10_11587157_EX-4.10_MarketingAgreement_ResellerAgreement".
# No answer
# No answer.
# No answer.
# No answer. The provided context does not mention a "non-disparagement" clause or statement in the document.
# No answer.
# Marketing Agreement, Reseller Agreement
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 116
#     113 retriever = vectorstore.as_retriever(search_kwargs={"k": min(len(splits), 4)})
#     115 # Ask questions about the document
# --> 116 doc_results = ask_questions(doc_name, retriever)
#     117 results[doc_name] = doc_results
#     119 # Increment the counter
#
# Cell In[6], line 62, in ask_questions(document_name, retriever)
#      59 chain = LLMChain(llm=llama_model, prompt=prompt_template)
#      61 # Ask the question using the LLM
# ---> 62 answer = chain.run({"context": context, "question": question})
#      63 print(answer)
#      64 answers[question] = answer
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:148, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     146     warned = True
#     147     emit_warning()
# --> 148 return wrapped(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/langchain/chains/base.py:595, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     593     if len(args) != 1:
#     594         raise ValueError("`run` supports only one positional argument.")
# --> 595     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     596         _output_key
#     597     ]
#     599 if kwargs and not args:
#     600     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     601         _output_key
#     602     ]
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:148, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     146     warned = True
#     147     emit_warning()
# --> 148 return wrapped(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/langchain/chains/base.py:378, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     346 """Execute the chain.
#     347
#     348 Args:
#    (...)
#     369         `Chain.output_keys`.
#     370 """
#     371 config = {
#     372     "callbacks": callbacks,
#     373     "tags": tags,
#     374     "metadata": metadata,
#     375     "run_name": run_name,
#     376 }
# --> 378 return self.invoke(
#     379     inputs,
#     380     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     381     return_only_outputs=return_only_outputs,
#     382     include_run_info=include_run_info,
#     383 )
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/langchain/chains/base.py:163, in Chain.invoke(self, input, config, **kwargs)
#     161 except BaseException as e:
#     162     run_manager.on_chain_error(e)
# --> 163     raise e
#     164 run_manager.on_chain_end(outputs)
#     166 if include_run_info:
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/langchain/chains/base.py:153, in Chain.invoke(self, input, config, **kwargs)
#     150 try:
#     151     self._validate_inputs(inputs)
#     152     outputs = (
# --> 153         self._call(inputs, run_manager=run_manager)
#     154         if new_arg_supported
#     155         else self._call(inputs)
#     156     )
#     158     final_outputs: Dict[str, Any] = self.prep_outputs(
#     159         inputs, outputs, return_only_outputs
#     160     )
#     161 except BaseException as e:
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/langchain/chains/llm.py:126, in LLMChain._call(self, inputs, run_manager)
#     121 def _call(
#     122     self,
#     123     inputs: Dict[str, Any],
#     124     run_manager: Optional[CallbackManagerForChainRun] = None,
#     125 ) -> Dict[str, str]:
# --> 126     response = self.generate([inputs], run_manager=run_manager)
#     127     return self.create_outputs(response)[0]
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/langchain/chains/llm.py:138, in LLMChain.generate(self, input_list, run_manager)
#     136 callbacks = run_manager.get_child() if run_manager else None
#     137 if isinstance(self.llm, BaseLanguageModel):
# --> 138     return self.llm.generate_prompt(
#     139         prompts,
#     140         stop,
#     141         callbacks=callbacks,
#     142         **self.llm_kwargs,
#     143     )
#     144 else:
#     145     results = self.llm.bind(stop=stop, **self.llm_kwargs).batch(
#     146         cast(List, prompts), {"callbacks": callbacks}
#     147     )
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/langchain_core/language_models/llms.py:633, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     625 def generate_prompt(
#     626     self,
#     627     prompts: List[PromptValue],
#    (...)
#     630     **kwargs: Any,
#     631 ) -> LLMResult:
#     632     prompt_strings = [p.to_string() for p in prompts]
# --> 633     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/langchain_core/language_models/llms.py:803, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     788 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     789     run_managers = [
#     790         callback_manager.on_llm_start(
#     791             dumpd(self),
#    (...)
#     801         )
#     802     ]
# --> 803     output = self._generate_helper(
#     804         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     805     )
#     806     return output
#     807 if len(missing_prompts) > 0:
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/langchain_core/language_models/llms.py:670, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     668     for run_manager in run_managers:
#     669         run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 670     raise e
#     671 flattened_outputs = output.flatten()
#     672 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/langchain_core/language_models/llms.py:657, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     647 def _generate_helper(
#     648     self,
#     649     prompts: List[str],
#    (...)
#     653     **kwargs: Any,
#     654 ) -> LLMResult:
#     655     try:
#     656         output = (
# --> 657             self._generate(
#     658                 prompts,
#     659                 stop=stop,
#     660                 # TODO: support multiple run managers
#     661                 run_manager=run_managers[0] if run_managers else None,
#     662                 **kwargs,
#     663             )
#     664             if new_arg_supported
#     665             else self._generate(prompts, stop=stop)
#     666         )
#     667     except BaseException as e:
#     668         for run_manager in run_managers:
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/langchain_community/llms/ollama.py:417, in Ollama._generate(self, prompts, stop, images, run_manager, **kwargs)
#     415 generations = []
#     416 for prompt in prompts:
# --> 417     final_chunk = super()._stream_with_aggregation(
#     418         prompt,
#     419         stop=stop,
#     420         images=images,
#     421         run_manager=run_manager,
#     422         verbose=self.verbose,
#     423         **kwargs,
#     424     )
#     425     generations.append([final_chunk])
#     426 return LLMResult(generations=generations)
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/langchain_community/llms/ollama.py:326, in _OllamaCommon._stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     317 def _stream_with_aggregation(
#     318     self,
#     319     prompt: str,
#    (...)
#     323     **kwargs: Any,
#     324 ) -> GenerationChunk:
#     325     final_chunk: Optional[GenerationChunk] = None
# --> 326     for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     327         if stream_resp:
#     328             chunk = _stream_response_to_generation_chunk(stream_resp)
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/langchain_community/llms/ollama.py:172, in _OllamaCommon._create_generate_stream(self, prompt, stop, images, **kwargs)
#     164 def _create_generate_stream(
#     165     self,
#     166     prompt: str,
#    (...)
#     169     **kwargs: Any,
#     170 ) -> Iterator[str]:
#     171     payload = {"prompt": prompt, "images": images}
# --> 172     yield from self._create_stream(
#     173         payload=payload,
#     174         stop=stop,
#     175         api_url=f"{self.base_url}/api/generate",
#     176         **kwargs,
#     177     )
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/langchain_community/llms/ollama.py:231, in _OllamaCommon._create_stream(self, api_url, payload, stop, **kwargs)
#     224 else:
#     225     request_payload = {
#     226         "prompt": payload.get("prompt"),
#     227         "images": payload.get("images", []),
#     228         **params,
#     229     }
# --> 231 response = requests.post(
#     232     url=api_url,
#     233     headers={
#     234         "Content-Type": "application/json",
#     235         **(self.headers if isinstance(self.headers, dict) else {}),
#     236     },
#     237     json=request_payload,
#     238     stream=True,
#     239     timeout=self.timeout,
#     240 )
#     241 response.encoding = "utf-8"
#     242 if response.status_code != 200:
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.local/share/virtualenvs/KGRAG-fgso8mNi/lib/python3.11/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.8/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1390, in HTTPConnection.getresponse(self)
#    1388 try:
#    1389     try:
# -> 1390         response.begin()
#    1391     except ConnectionError:
#    1392         self.close()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.8/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File /opt/homebrew/Cellar/python@3.11/3.11.8/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.11/3.11.8/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

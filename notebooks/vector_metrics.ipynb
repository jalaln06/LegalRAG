# %%
import pandas as pd

master_clauses_path = 'master_an.csv'
processed_vector_path = 'vector_ans.csv'

master_clauses_df = pd.read_csv(master_clauses_path, delimiter=';')
processed_vector_df = pd.read_csv(processed_vector_path, delimiter=';')

master_clauses_df.head(), processed_vector_df.head()
# Out:
# (   Unnamed: 0                                      Document Name  \
#  0         192   ABILITYINC_06_15_2020-EX-4.25-SERVICES AGREEMENT
#  1         131  AlliedEsportsEntertainmentInc_20190815_8-K_EX-...
#  2         438     Antares Pharma, Inc. - Manufacturing Agreement
#  3         229  ASPIRITYHOLDINGSLLC_05_07_2012-EX-10.6-OUTSOUR...
#  4         247  AzulSa_20170303_F-1A_EX-10.3_9943903_EX-10.3_M...
#
#                                       Document Name.1  \
#  0                             ['Services Agreement']
#  1                ['JOINT CONTENT LICENSE AGREEMENT']
#  2                        ['Manufacturing Agreement']
#  3                          ['OUTSOURCING AGREEMENT']
#  4  ['Amendment n 01   to the Global Maintenance A...
#
#                                  Document Name-Answer  \
#  0                                 Services Agreement
#  1                    JOINT CONTENT LICENSE AGREEMENT
#  2                            Manufacturing Agreement
#  3                              OUTSOURCING AGREEMENT
#  4  Amendment n 01   to the Global Maintenance Agr...
#
#                                               Parties  \
#  0  ['"Provider"', 'TELCOSTAR PTE, LTD.', 'Each of...
#  1  ['WPT Enterprises, Inc.', 'Zynga US', '("Zynga...
#  2  ['Antares and AMAG are sometimes referred to h...
#  3  ['Twin Cities Power Holdings, LLC', 'Company',...
#  4  ['Hereinafter individually referred to as the ...
#
#                                        Parties-Answer  \
#  0  [ * * * ] ("Provider"); TELCOSTAR PTE, LTD.; A...
#  1  WPT Enterprises, Inc. (?WPT?); ZYNGA INC. (?Zy...
#  2  Antares Pharma, Inc. ("Antares"); AMAG Pharmac...
#  3  Twin Cities Power Holdings, LLC ("Company"); R...
#  4  AZUL LINHAS AEREAS BRASILEIRAS S/A ("Company",...
#
#                  Agreement Date Agreement Date-Answer  \
#  0          ['October 1, 2019']               10/1/19
#  1         ['February 1, 2018']                2/1/18
#  2  ['20th day of March, 2018']               3/20/18
#  3      ['this  day of , 2012']            []/[]/2012
#  4        ['January 6th, 2016']                1/6/16
#
#                                        Effective Date Effective Date-Answer  \
#  0                               ['November 1, 2019']               11/1/19
#  1                               ['February 1, 2018']                2/1/18
#  2                        ['20th day of March, 2018']               3/20/18
#  3  ['this  day of , 2012<omitted>This Agreement s...            []/[]/2012
#  4  ['This Amendment shall enter into force on the...                1/6/16
#
#     ... Warranty Duration Warranty Duration-Answer  \
#  0  ...                []                       No
#  1  ...                []                       No
#  2  ...                []                       No
#  3  ...                []                       No
#  4  ...                []                       No
#
#                                             Insurance Insurance-Answer  \
#  0                                                 []               No
#  1  ['Each party agrees to carry liability insuran...              Yes
#  2  ['If requested each Party will provide the oth...              Yes
#  3  ["The Contractor maintains insurance, which is...              Yes
#  4                                                 []               No
#
#                                   Covenant Not To Sue  \
#  0                                                 []
#  1  ["Licensee will not, at any time during or aft...
#  2                                                 []
#  3                                                 []
#  4                                                 []
#
#    Covenant Not To Sue-Answer  \
#  0                         No
#  1                        Yes
#  2                         No
#  3                         No
#  4                         No
#
#                               Third Party Beneficiary  \
#  0                                                 []
#  1                                                 []
#  2                                                 []
#  3  ['Any  successor of any party or of any such c...
#  4                                                 []
#
#    Third Party Beneficiary-Answer  \
#  0                             No
#  1                             No
#  2                             No
#  3                            Yes
#  4                             No
#
#                                 Standardized Filename  \
#  0   ABILITYINC-06-15-2020-EX-4.25-SERVICES AGREEMENT
#  1  AlliedEsportsEntertainmentInc-20190815-8-K-EX-...
#  2     Antares Pharma, Inc. - Manufacturing Agreement
#  3  ASPIRITYHOLDINGSLLC-05-07-2012-EX-10.6-OUTSOUR...
#  4  AzulSa-20170303-F-1A-EX-10.3-9943903-EX-10.3-M...
#
#                        Enhanced Standardized Filename
#  0    abilityinc 06 15 2020 ex 425 services agreement
#  1  alliedesportsentertainmentinc 20190815 8 k ex ...
#  2         antares pharma inc manufacturing agreement
#  3  aspirityholdingsllc 05 07 2012 ex 106 outsourc...
#  4  azulsa 20170303 f 1a ex 103 9943903 ex 103 mai...
#
#  [5 rows x 86 columns],
#                                         Document Name Warranty Duration  \
#  0   ABILITYINC_06_15_2020-EX-4.25-SERVICES AGREEMENT         No answer
#  1  AlliedEsportsEntertainmentInc_20190815_8-K_EX-...         No answer
#  2     Antares Pharma, Inc. - Manufacturing Agreement         No answer
#  3  ASPIRITYHOLDINGSLLC_05_07_2012-EX-10.6-OUTSOUR...         No answer
#  4  AzulSa_20170303_F-1A_EX-10.3_9943903_EX-10.3_M...         No answer
#
#    Governing Law                                        Exclusivity  \
#  0     No answer                                 Services Agreement
#  1     No answer  The good will and marks are exclusively those ...
#  2     No answer                                          No answer
#  3     No answer                                          No answer
#  4     No answer                                          No answer
#
#    Price Restrictions                                    Anti-Assignment  \
#  0          No answer  The answer to your question based on the provi...
#  1          No answer                                          No answer
#  2          No answer                                          No answer
#  3          No answer                                          No answer
#  4          No answer                                          No answer
#
#    Uncapped Liability Irrevocable Or Perpetual License  \
#  0          No answer                        No answer
#  1          No answer               Perpetual license.
#  2          No answer                        No answer
#  3          No answer                        No answer
#  4          No answer                        No answer
#
#                                   Covenant Not To Sue Liquidated Damages  ...  \
#  0                                          No answer          No answer  ...
#  1  The covenant not to sue states that Zynga will...          No answer  ...
#  2                                          No answer          No answer  ...
#  3                                          No answer          No answer  ...
#  4                                          No answer          No answer  ...
#
#                                        Agreement Date  \
#  0  The agreement date is not explicitly stated in...
#  1                                          No answer
#  2                                          No answer
#  3                                          No answer
#  4                                          No answer
#
#                            Affiliate License-Licensee  \
#  0                                          No answer
#  1  WPT Enterprises, Inc. and Zynga Game Ireland L...
#  2                                          No answer
#  3                                          No answer
#  4                                          No answer
#
#    Termination For Convenience             Rofr/Rofo/Rofn  \
#  0                   No answer         Services Agreement
#  1                   No answer  CONTENT LICENSE AGREEMENT
#  2                   No answer                  No answer
#  3                   No answer      OUTSOURCING AGREEMENT
#  4                   No answer                  No answer
#
#    Notice Period To Terminate Renewal Renewal Term  \
#  0                           90 days.    No answer
#  1                          No answer    No answer
#  2                          No answer    No answer
#  3                          No answer    No answer
#  4                          No answer    No answer
#
#                                    Source Code Escrow  \
#  0                                          No answer
#  1  The source code for this document is "ALLIED E...
#  2                                          No answer
#  3                                          No answer
#  4                                          No answer
#
#                               No-Solicit Of Employees Audit Rights  \
#  0                                          No answer    No answer
#  1                                          No answer    No answer
#  2  Each Party further covenants, represents and w...    No answer
#  3                                          No answer    No answer
#  4                                          No answer    No answer
#
#                                     Non-Disparagement
#  0  The non-disparagement clause is not explicitly...
#  1                                          No answer
#  2                                          No answer
#  3                                          No answer
#  4                                          No answer
#
#  [5 rows x 42 columns])

# %%
processed_vector_df = processed_vector_df.rename(
    columns={col: col + "_llm_vector" for col in processed_vector_df.columns if col != 'Document Name'})

merged_df = pd.merge(master_clauses_df, processed_vector_df, on='Document Name')

sorted_columns = ['Document Name'] + sorted([col for col in merged_df.columns if col != 'Document Name'])
merged_df = merged_df[sorted_columns]
merged_df.replace('No asnwer', 'No', inplace=True)

merged_df.head()
# Out:
#                                        Document Name  \
# 0   ABILITYINC_06_15_2020-EX-4.25-SERVICES AGREEMENT
# 1  AlliedEsportsEntertainmentInc_20190815_8-K_EX-...
# 2     Antares Pharma, Inc. - Manufacturing Agreement
# 3  ASPIRITYHOLDINGSLLC_05_07_2012-EX-10.6-OUTSOUR...
# 4  AzulSa_20170303_F-1A_EX-10.3_9943903_EX-10.3_M...
#
#   Affiliate License-Licensee Affiliate License-Licensee-Answer  \
# 0                         []                                No
# 1                         []                                No
# 2                         []                                No
# 3                         []                                No
# 4                         []                                No
#
#                Affiliate License-Licensee_llm_vector  \
# 0                                          No answer
# 1  WPT Enterprises, Inc. and Zynga Game Ireland L...
# 2                                          No answer
# 3                                          No answer
# 4                                          No answer
#
#   Affiliate License-Licensor Affiliate License-Licensor-Answer  \
# 0                         []                                No
# 1                         []                                No
# 2                         []                                No
# 3                         []                                No
# 4                         []                                No
#
#   Affiliate License-Licensor_llm_vector               Agreement Date  \
# 0                             No answer          ['October 1, 2019']
# 1  Zynga Inc. and WPT Enterprises, Inc.         ['February 1, 2018']
# 2                             No answer  ['20th day of March, 2018']
# 3                             No answer      ['this  day of , 2012']
# 4                             No answer        ['January 6th, 2016']
#
#   Agreement Date-Answer                          Agreement Date_llm_vector  \
# 0               10/1/19  The agreement date is not explicitly stated in...
# 1                2/1/18                                          No answer
# 2               3/20/18                                          No answer
# 3            []/[]/2012                                          No answer
# 4                1/6/16                                          No answer
#
#    ... Unlimited/All-You-Can-Eat-License  \
# 0  ...                                []
# 1  ...                                []
# 2  ...                                []
# 3  ...                                []
# 4  ...                                []
#
#   Unlimited/All-You-Can-Eat-License-Answer  \
# 0                                       No
# 1                                       No
# 2                                       No
# 3                                       No
# 4                                       No
#
#   Unlimited/All-You-Can-Eat-License_llm_vector Unnamed: 0 Volume Restriction  \
# 0                                    No answer        192                 []
# 1                                    No answer        131                 []
# 2                                    No answer        438                 []
# 3                                    No answer        229                 []
# 4                                    No answer        247                 []
#
#   Volume Restriction-Answer Volume Restriction_llm_vector Warranty Duration  \
# 0                        No                     No answer                []
# 1                        No                     No answer                []
# 2                        No                     No answer                []
# 3                        No                     No answer                []
# 4                        No                     No answer                []
#
#   Warranty Duration-Answer Warranty Duration_llm_vector
# 0                       No                    No answer
# 1                       No                    No answer
# 2                       No                    No answer
# 3                       No                    No answer
# 4                       No                    No answer
#
# [5 rows x 127 columns]

# %%
merged_df.head()
# Out:
#                                        Document Name  \
# 0   ABILITYINC_06_15_2020-EX-4.25-SERVICES AGREEMENT
# 1  AlliedEsportsEntertainmentInc_20190815_8-K_EX-...
# 2     Antares Pharma, Inc. - Manufacturing Agreement
# 3  ASPIRITYHOLDINGSLLC_05_07_2012-EX-10.6-OUTSOUR...
# 4  AzulSa_20170303_F-1A_EX-10.3_9943903_EX-10.3_M...
#
#   Affiliate License-Licensee Affiliate License-Licensee-Answer  \
# 0                         []                                No
# 1                         []                                No
# 2                         []                                No
# 3                         []                                No
# 4                         []                                No
#
#                Affiliate License-Licensee_llm_vector  \
# 0                                          No answer
# 1  WPT Enterprises, Inc. and Zynga Game Ireland L...
# 2                                          No answer
# 3                                          No answer
# 4                                          No answer
#
#   Affiliate License-Licensor Affiliate License-Licensor-Answer  \
# 0                         []                                No
# 1                         []                                No
# 2                         []                                No
# 3                         []                                No
# 4                         []                                No
#
#   Affiliate License-Licensor_llm_vector               Agreement Date  \
# 0                             No answer          ['October 1, 2019']
# 1  Zynga Inc. and WPT Enterprises, Inc.         ['February 1, 2018']
# 2                             No answer  ['20th day of March, 2018']
# 3                             No answer      ['this  day of , 2012']
# 4                             No answer        ['January 6th, 2016']
#
#   Agreement Date-Answer                          Agreement Date_llm_vector  \
# 0               10/1/19  The agreement date is not explicitly stated in...
# 1                2/1/18                                          No answer
# 2               3/20/18                                          No answer
# 3            []/[]/2012                                          No answer
# 4                1/6/16                                          No answer
#
#    ... Unlimited/All-You-Can-Eat-License  \
# 0  ...                                []
# 1  ...                                []
# 2  ...                                []
# 3  ...                                []
# 4  ...                                []
#
#   Unlimited/All-You-Can-Eat-License-Answer  \
# 0                                       No
# 1                                       No
# 2                                       No
# 3                                       No
# 4                                       No
#
#   Unlimited/All-You-Can-Eat-License_llm_vector Unnamed: 0 Volume Restriction  \
# 0                                    No answer        192                 []
# 1                                    No answer        131                 []
# 2                                    No answer        438                 []
# 3                                    No answer        229                 []
# 4                                    No answer        247                 []
#
#   Volume Restriction-Answer Volume Restriction_llm_vector Warranty Duration  \
# 0                        No                     No answer                []
# 1                        No                     No answer                []
# 2                        No                     No answer                []
# 3                        No                     No answer                []
# 4                        No                     No answer                []
#
#   Warranty Duration-Answer Warranty Duration_llm_vector
# 0                       No                    No answer
# 1                       No                    No answer
# 2                       No                    No answer
# 3                       No                    No answer
# 4                       No                    No answer
#
# [5 rows x 127 columns]

# %%
merged_df.to_csv("full_csv.csv")

# %%
from langchain import LLMChain, PromptTemplate
from langchain.llms import Ollama
import re

prompt_template = """
You are a tool to score answers. Consider the following correct answer and a llm generated answer.
Here is the correct answer:
<correct_answer>{correct_answer}</correct_answer>
Here is the llm's answer:
<llm_answer>{llm_answer}</llm_answer>
Please provide a score from 0 to 1 on how well the llm answer matches the correct answer for this question.
The score should be high if the answers say essentially the same thing.
The score should be lower if some facts are missing or incorrect, or if extra unnecessary facts have been included.
The score should be 0 for entirely wrong answers. Put the score in <SCORE> tags.
Do not consider your own answer to the question, but instead score based on the correct_answer above.
Write only score in SCORE tag.
"""

prompt = PromptTemplate(input_variables=["correct_answer", "llm_answer"], template=prompt_template)

llm = Ollama(model="llama3:latest")

chain_for_positivescoring = LLMChain(llm=llm, prompt=prompt)

negative_prompt_template = """
You are a tool to score answers. Consider the following correct answer and a llm generated answer. In this case. LLM answer should be as close as possible to saying that it has no answer.
Here is the correct answer:
<correct_answer>No answer</correct_answer>
Here is the llm's answer:
<llm_answer>{llm_answer}</llm_answer>
Please provide a score from 0 to 1 on how well the llm answer matches the correct answer for this question.
The score should be high if the answers say essentially the same thing.
The score should be lower if some facts are missing or incorrect, or if extra unnecessary facts have been included.
The score should be 0 for entirely wrong answers. Put the score in <SCORE> tags.
Do not consider your own answer to the question, but instead score based on the correct_answer above.
Write only score in SCORE tag.
"""

negative_prompt = PromptTemplate(input_variables=["llm_answer"], template=negative_prompt_template)
chain_for_negativescoring = LLMChain(llm=llm, prompt=negative_prompt)

# %%
import pandas as pd

file_path = 'full_csv_processed.csv'
data = pd.read_csv(file_path, delimiter=';')

data = data.drop(columns=['Unnamed: 0.1', 'Unnamed: 0', 'Enhanced Standardized Filename', 'Standardized Filename'],
                 errors='ignore')
data.rename(columns={'Notice Period To Terminate Renewal- Answer': 'Notice Period To Terminate Renewal-Answer'},
            inplace=True)

data.rename(columns={'Document Name': 'Temp Name'}, inplace=True)
data.rename(columns={'Document Name-Answer': 'Document Name'}, inplace=True)
data.rename(columns={'Temp Name': 'Document Name-Answer'}, inplace=True)
columns = data.columns


def scoring(correct_answer, llm_answer, chain):
    def extract_score(response):
        match = re.search(r'<SCORE>(.*?)</SCORE>', response)
        return float(match.group(1)) if match else None

    try:
        for _ in range(3):
            response = chain.run({"correct_answer": correct_answer, "llm_answer": llm_answer})
            score = extract_score(response)
            if score is not None:
                return score
    except Exception as e:
        print(f"An error occurred: {e}")
    return 0


TN = 0
FP = 0
FN = 0
TP = 0

for i in range(2, len(columns), 3):
    col_base = '-'.join(columns[i].split('-')[:-1])

    if f'{col_base}-Answer' in data.columns and f'{col_base}_llm_vector' in data.columns:
        correct_answer = data[f'{col_base}-Answer']
        llm_answer = data[f'{col_base}_llm_vector']
        true_answer = data[f'{col_base}']
        for j in range(len(data)):
            correct = str(correct_answer[j]).strip()
            llm = str(llm_answer[j]).strip()
            true = str(true_answer[j].strip())
            if correct in ['No', ''] and llm == 'No answer':
                TN += 1
            elif correct in ['No', ''] and llm != 'No answer':
                score = scoring(true, llm, chain_for_negativescoring)
                if score > 0.5:
                    TN += 1
                else:
                    FP += 1
            elif correct not in ['No', ''] and llm == 'No answer':
                FN += 1
            elif correct not in ['No', ''] and llm != 'No answer':
                # Call positive scoring function
                score = scoring(true, llm, chain_for_positivescoring)
                if score > 0.5:
                    TP += 1
                else:
                    FN += 1
    else:
        print(f"Skipping column base: {col_base} due to missing expected columns")

# Results
results = {
    'True Negative': TN,
    'False Positive': FP,
    'False Negative': FN,
    'True Positive': TP
}

results

# %%
from sklearn.metrics import roc_auc_score

precision = TP / (TP + FP) if (TP + FP) != 0 else 0
recall = TP / (TP + FN) if (TP + FN) != 0 else 0

f1 = (2 * precision * recall) / (precision + recall) if (precision + recall) != 0 else 0

y_true = [0] * (TN + FP) + [1] * (FN + TP)
y_scores = [0] * TN + [1] * FP + [0] * FN + [1] * TP

roc_auc = roc_auc_score(y_true, y_scores)

print("Results:", results)
print("F1 Score:", f1)
print("ROC AUC Score:", roc_auc)
# Out:
# Results: {'True Negative': 1405, 'False Positive': 282, 'False Negative': 830, 'True Positive': 148}
# F1 Score: 0.21022727272727273
# ROC AUC Score: 0.4920843015820487
